# %%
## Syntax is a correct arrangement of symbols of words in a code.

# %%
## Semantics is about what the code is supposed to do when it runs.

# %%
print("hello world")
# Out:
# hello world

# %%
##basic calculaations:
a = int(input("enter first number"))
b = int(input("enter second number"))
print("the sum is", a + b)
print("the difference is", a - b)
print("the product is", a * b)
print("the quotient is", a / b)
print("the remainder is", a % b)
# Out:
# the sum is 101
# the difference is -11
# the product is 2520
# the quotient is 0.8035714285714286
# the remainder is 45
